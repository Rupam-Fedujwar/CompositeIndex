# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_excel(r"D:\Ph.D._Details\02_PhD_Objectives\01_Objective_I\Expert_Opinion_Survey\06_DataForAnalysis\Recent_Expert_Opinion_Final_Data.xlsx")
df = pd.read_excel(r"D:\Ph.D._Details\02_PhD_Objectives\01_Objective_I\Expert_Opinion_Survey\06_DataForAnalysis\SurveyData07.xlsx")

# %%
df
# Out:
#     OC_SA  OC_TTR  OC_EF  SA_TTR  SA_EF  TTR_EF  Sr. No.                Name  \
# 0       5       5      1      -3     -7      -7        1  Prakash Chand Arya
# 1       7       7     -4      -5     -4      -6        2  Nabamalika Joardar
# 2       7       7     -5      -7     -7      -8        3             Unknown
# 3      -6      -7     -7      -6     -5      -5        4             Anonyms
# 4       5       4     -5       5     -5      -7        5              Rajesh
# ..    ...     ...    ...     ...    ...     ...      ...                 ...
# 58      1      -2     -7      -3     -7      -7       59           Anonymous
# 59      7       7     -5      -7     -7      -8       60           Anonymous
# 60     -6      -7     -7      -6     -5      -5       61           Anonymous
# 61     -6      -5     -5      -5     -9      -9       62       Ravindra Page
# 62     -5       5     -5       6      6       6       63          Mani Yadav
#
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df['Your role'].unique()
# Out:
# array(['Industry Professional', 'Policy maker or Adviser',
#        'Service operator or service provider', 'Other',
#        'Researcher or Academician'], dtype=object)

# %%
len(df)
# Out:
# 63

# %%
# Expert aggregation based on role
expert = df.copy()
expert['count'] = 1
expert_role =  expert.groupby(['Your role'])['count'].sum()

# Data to plot
labels = expert_role.index
sizes = expert_role.values  # These values represent the percentages for each category
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'pink']
explode = (0, 0.2, 0, 0, 0)  # Explode a slice (i.e., 'B')

# Create the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140, textprops={'fontsize': 18})
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Researcher/ Academician', 'Policy maker / adviser', 'Other', 'Industry  professional', 'Service operator / service provider']
sizes = [30.2, 12.7, 14.3, 23.8, 19]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'pink']
explode = (0, 0.2, 0, 0, 0)


# Create the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140, textprops={'fontsize': 14})
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Researcher/ Academician', 'Policy maker / adviser', 'Other', 'Industry  professional', 'Service operator / service provider']
sizes = [30.2, 12.7, 14.3, 23.8, 19]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'pink']
explode = (0, 0.2, 0, 0, 0)

# Adjust labels to two lines
wrapped_labels = [label[:len(label)//2] + '\n' + label[len(label)//2:] if len(label) > 8 else label for label in labels]

# Create the pie chart
plt.pie(sizes, explode=explode, labels=wrapped_labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140, textprops={'fontsize': 18})
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Researcher/ Academician', 'Policy maker / adviser', 'Other', 'Industry professional', 'Service operator / service provider']
sizes = [30.2, 12.7, 14.3, 23.8, 19]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'pink']
explode = (0, 0.2, 0, 0, 0)

# Adjust labels to two lines
wrapped_labels = [label[:len(label)//2] + '\n' + label[len(label)//2:] if len(label) > 10 else label for label in labels]

# Create the pie chart
plt.pie(sizes, explode=explode, labels=wrapped_labels, colors=colors, autopct='%1.1f%%', pctdistance=0.85, shadow=True, startangle=140, textprops={'fontsize': 12})
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
expert_role
# Out:
# Your role
# Industry Professional                   15
# Other                                    9
# Policy maker or Adviser                  8
# Researcher or Academician               19
# Service operator or service provider    12
# Name: count, dtype: int64

# %%
# Plot a bar chart for gender distribution with rotated x-axis labels and percentages
plt.figure(figsize=(8, 6))
gender_counts = expert['Gender'].value_counts()
gender_percentage = gender_counts / gender_counts.sum() * 100
gender_counts.plot(kind='bar', color=['yellowgreen', 'lightcoral', 'green', 'purple'])
# plt.xlabel('Gender')
#plt.ylabel('Number of experts', fontsize=14)

# Remove the grid
plt.grid(False)

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=0, fontsize=16)
#plt.yticks(rotation=0, fontsize=16)

# Remove y-ticks
plt.yticks([])

# Add percentages above the bars with increased font size
for i, count in enumerate(gender_counts):
    plt.text(i, count + 0.5, f'{gender_percentage[i]:.1f}%', ha='center', fontsize=16)

plt.show()

# %%
gender_counts
# Out:
# Male                47
# Female              13
# Did not revealed     3
# Name: Gender, dtype: int64

# %%
# Calculate experience category percentages
experience_percentages = expert['Experience in above stated Role'].value_counts()

# Sort the index in the desired order
experience_percentages = experience_percentages.loc[['5 years or Less', 'Between 5-10 years', 'Between 10-15 years', 'Between 15-20 years', '20 Years or More']]

# Plot line plot for experience category percentages
plt.figure(figsize=(8, 6))
experience_percentages.plot(marker='o',  linestyle='-', color='b', markersize=8)

# Remove the grid
plt.grid(False)

# Set y-axis limit starting from 0
plt.ylim(0, experience_percentages.max() + 5)

# plt.title('Experience Category Distribution')
# plt.xlabel('Experience Category')
plt.ylabel('Number of experts', fontsize=14)
plt.xticks(rotation=45,fontsize=16)
# plt.grid(True)
plt.show()

# %%
experience_percentages_ = experience_percentages / experience_percentages.sum() * 100
experience_percentages_
# Out:
# 5 years or Less        28.571429
# Between 5-10 years     19.047619
# Between 10-15 years    20.634921
# Between 15-20 years    11.111111
# 20 Years or More       20.634921
# Name: Experience in above stated Role, dtype: float64

# %%
import matplotlib.pyplot as plt

# Data as lists (assuming "years or Less" is a category)
experience_labels = ["0-5 years", "5-10 years", "10-15 years", "15-20 years", "20 years and More"]
experience_percentages = [28.571,19.047,20.635,11.111,20.635]

# Create the line plot
plt.figure(figsize=(8, 6))  # Set the figure size
plt.plot(experience_labels, experience_percentages, marker='o', linestyle='-', color='b', markersize=8)


# Customize the plot
#plt.xlabel("Years of Experience")
plt.ylabel("Percentage", fontsize=16)
#plt.title("Distribution of Experience")
plt.xticks(rotation=45,fontsize=16) # Rotate x-axis labels for better readability
plt.yticks(fontsize=16)

# Display the plot
plt.grid(False)
plt.ylim(0, 35)
plt.tight_layout()
plt.show()

# %%
df_01 = expert.groupby(['Your role', "Experience in above stated Role"])['count'].sum()

df_01 = pd.DataFrame(df_01)
# Assuming you have a DataFrame named 'df_01' with the specified columns
# Replace 'count' with your actual column name

# Reset index to convert the result of groupby into a DataFrame

df_01 = df_01.reset_index()

# Define the desired order for the x-axis categories
experience_order = ['5 years or Less', 'Between 5-10 years', 'Between 10-15 years', 'Between 15-20 years', '20 Years or More']

# Set the style of seaborn
sns.set(style="whitegrid")

# Create a grouped bar plot with the specified order for the x-axis categories
plt.figure(figsize=(12, 8))
sns.barplot(x='Experience in above stated Role', y='count', hue='Your role', data=df_01, palette='viridis', order=experience_order)


# Add labels and title
# plt.title('Grouped Bar Plot of Count by Experience for Each Role')
# plt.xlabel('Experience in above stated Role')
plt.ylabel('Number of experts')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=0)

# Show the plot
plt.show()

# %%
expert.head(4)
# Out:
#    Sr. No.                Name             Designation  \
# 0        1  Prakash Chand Arya       Transport Planner
# 1        2  Nabamalika Joardar  Head - Innovation Unit
# 2        3  Nabamalika Joardar  Head - Innovation Unit
# 3        4             Anonyms          Deport Manager
#
#                            Affiliation                             Your role  \
# 0                                 ITPI                 Industry Professional
# 1  National Institute of Urban Affairs               Policy maker or Adviser
# 2  National Institute of Urban Affairs               Policy maker or Adviser
# 3                Meerut Electric Buses  Service operator or service provider
#
#   Experience in above stated Role  A-Occupancy B-Service availability  \
# 0             Between 10-15 years                                  B5
# 1             Between 10-15 years                                  B7
# 2             Between 10-15 years                                  B7
# ...

# %% [markdown]
# ## Further analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Given data previous data
# data = {
#     'max': ['top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3'],
#     'pair': ['OC_EF', 'OC_EF', 'OC_EF', 'OC_SA', 'OC_SA', 'OC_SA', 'OC_TTR', 'OC_TTR', 'OC_TTR', 'SA_EF', 'SA_EF', 'SA_EF', 'SA_TTR', 'SA_TTR', 'SA_TTR', 'TTR_EF', 'TTR_EF', 'TTR_EF'],
#     'Freq': [1, 5, 6, 4, 1, 5, 1, 1, 1, 1, 7, 1, 2, 3, 3, 8, 0, 1]
# }


data = {
    'max': ['top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3', 'top1', 'top2', 'top3'],
    'pair': ['OC_EF', 'OC_EF', 'OC_EF', 'OC_SA', 'OC_SA', 'OC_SA', 'OC_TTR', 'OC_TTR', 'OC_TTR', 'SA_EF', 'SA_EF', 'SA_EF', 'SA_TTR', 'SA_TTR', 'SA_TTR', 'TTR_EF', 'TTR_EF', 'TTR_EF'],
    'Freq': [1, 5, 6, 4, 1, 5, 1, 1, 1, 1, 7, 1, 2, 3, 3, 8, 0, 1]
        }

df = pd.DataFrame(data)

# Pivot the DataFrame for a stacked bar plot
df_pivot = df.pivot(index='pair', columns='max', values='Freq').fillna(0)

# Create a stacked bar plot
colors = ['skyblue', 'lightgreen', 'lightcoral']
ax = df_pivot.plot(kind='bar', stacked=True, color=colors, figsize=(10, 6))

#colormap='viridis'

# Customize the plot
#plt.xlabel('Pair')
plt.ylabel('Frequency')
# plt.title('Stacked Bar Plot')
plt.legend(title='Rank', loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# # Aggregated AHP restuls

# %%
import matplotlib.pyplot as plt

# Data
attributes = ['Occupancy', 'Service availability', 'Travel Time Reliability', 'Environmental Factor']
weights = [0.212, 0.410, 0.291, 0.083]

# Create horizontal bar plot
plt.barh(attributes, weights, color='skyblue')
plt.xlabel('Weights')
# plt.title('Attribute Weights')

# Show the plot
plt.show()

# %%
# Your data
data = {
    'T*': [0.212, 0.409, 0.279, 0.099],
    'A*': [0.244, 0.372, 0.292, 0.091],
    'IP*': [0.236, 0.398, 0.276, 0.089],
    'S*': [0.182, 0.462, 0.268, 0.088],
    'P*': [0.179, 0.442, 0.294, 0.078],
    'O*': [0.179, 0.425, 0.344, 0.052]
}


# Create a DataFrame
df = pd.DataFrame(data, index=['OC', 'SA', 'TTR', 'EF'])

# Plotting
plt.figure(figsize=(2000, 1200))
df.plot(kind='bar', rot=0)

# Adding labels and title
# plt.xlabel('Attributes')
plt.ylabel('Weights')
# plt.title('Bar Plot')

# Adding legend
plt.legend()

# Remove grid lines
plt.grid(False)


# Show the plot
plt.show()

# %% [markdown]
# # AHP Results

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with the provided data
data = {
    "OC": [0.111, 0.191, 0.318],
    "SA": [0.263, 0.444, 0.735],
    "TTR": [0.177, 0.290, 0.490],
    "EF": [0.046,0.075,0.122]
}

df = pd.DataFrame(data)

# Create a box plot using Seaborn
plt.figure(figsize=(7, 5))
sns.boxplot(data=df)

# Remove the grid
plt.grid(False)

# Add labels and title
plt.ylabel('Weights')

# Show the plot
plt.show()
